# %% [markdown]
# # Pyplot/Seaborn Cheatsheet

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %% [markdown]
# ### 生成测试数据集

# %%
x = np.linspace(-3,3,50)

# %%
y1 = 2*x+1
y2 = x**2

# %%
plt.plot(x,y1)

# %%
plt.plot(x,y2)
